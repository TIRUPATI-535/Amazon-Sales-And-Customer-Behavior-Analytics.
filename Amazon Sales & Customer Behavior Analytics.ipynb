# %%
import pandas as pd

# %%
df=pd.read_csv('Amazondata.csv')

# %%
df
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  31-01-2023  CUST001504  Vihaan Sharma    P00014
# 1      ORD0000002  30-12-2023  CUST000178    Pooja Kumar    P00040
# 2      ORD0000003  10-05-2022  CUST047516    Sneha Singh    P00044
# 3      ORD0000004  18-07-2023  CUST030059   Vihaan Reddy    P00041
# 4      ORD0000005  04-02-2023  CUST048677  Aditya Kapoor    P00029
# ...           ...         ...         ...            ...       ...
# 99995  ORD0099996  07-03-2023  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  24-11-2021  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  29-04-2023  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  01-11-2021  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  04-12-2021  CUST029492   Sunita Reddy    P00019
#
#                ProductName           Category       Brand  Quantity  \
# 0               Drone Mini              Books   BrightLux         3
# ...

# %%
df.head()
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  31-01-2023  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  30-12-2023  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  10-05-2022  CUST047516    Sneha Singh    P00044
# 3  ORD0000004  18-07-2023  CUST030059   Vihaan Reddy    P00041
# 4  ORD0000005  04-02-2023  CUST048677  Aditya Kapoor    P00029
#
#            ProductName        Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini           Books   BrightLux         3     106.59
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03
# 3       Webcam Full HD  Home & Kitchen      Zenith         5      33.58
# 4              T-Shirt        Clothing    KiddoFun         2     515.64
#
#    Discount    Tax  ShippingCost  TotalAmount     PaymentMethod OrderStatus  \
# ...

# %%
df.tail()
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 99995  ORD0099996  07-03-2023  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  24-11-2021  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  29-04-2023  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  01-11-2021  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  04-12-2021  CUST029492   Sunita Reddy    P00019
#
#              ProductName           Category      Brand  Quantity  UnitPrice  \
# 99995  Memory Card 128GB        Electronics       Apex         2     492.34
# 99996        Car Charger  Sports & Outdoors       Apex         5     449.30
# 99997        Dress Shirt  Sports & Outdoors  BrightLux         4     232.40
# 99998        Car Charger  Sports & Outdoors   HomeEase         1     294.05
# 99999      LED Desk Lamp     Home & Kitchen   CoreTech         5     166.70
#
#        Discount     Tax  ShippingCost  TotalAmount     PaymentMethod  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderID        100000 non-null  object
#  1   OrderDate      100000 non-null  object
#  2   CustomerID     100000 non-null  object
#  3   CustomerName   100000 non-null  object
#  4   ProductID      100000 non-null  object
#  5   ProductName    100000 non-null  object
#  6   Category       100000 non-null  object
#  7   Brand          100000 non-null  object
#  8   Quantity       100000 non-null  int64
#  9   UnitPrice      100000 non-null  float64
#  10  Discount       99918 non-null   float64
#  11  Tax            100000 non-null  float64
#  12  ShippingCost   100000 non-null  float64
#  13  TotalAmount    100000 non-null  float64
#  14  PaymentMethod  100000 non-null  object
#  15  OrderStatus    100000 non-null  object
#  16  City           100000 non-null  object
# ...

# %%
df.describe()
# Out:
#             Quantity      UnitPrice      Discount            Tax  \
# count  100000.000000  100000.000000  99918.000000  100000.000000
# mean        3.001400     302.905748      0.074287      68.468902
# std         1.413548     171.840797      0.082590      74.131180
# min         1.000000       5.000000      0.000000       0.000000
# 25%         2.000000     154.190000      0.000000      15.920000
# 50%         3.000000     303.070000      0.050000      45.250000
# 75%         4.000000     451.500000      0.100000      96.060000
# max         5.000000     599.990000      0.300000     538.460000
#
#         ShippingCost    TotalAmount
# count  100000.000000  100000.000000
# mean        7.406660     918.256479
# std         4.324057     724.508332
# min         0.000000       4.270000
# 25%         3.680000     340.890000
# 50%         7.300000     714.315000
# 75%        11.150000    1349.765000
# max        15.000000    3534.980000

# %%
df.isnull().sum()
# Out:
# OrderID           0
# OrderDate         0
# CustomerID        0
# CustomerName      0
# ProductID         0
# ProductName       0
# Category          0
# Brand             0
# Quantity          0
# UnitPrice         0
# Discount         82
# Tax               0
# ShippingCost      0
# TotalAmount       0
# PaymentMethod     0
# OrderStatus       0
# City              0
# State             0
# Country           0
# SellerID          0
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# OrderID          0
# OrderDate        0
# CustomerID       0
# CustomerName     0
# ProductID        0
# ProductName      0
# Category         0
# Brand            0
# Quantity         0
# UnitPrice        0
# Discount         0
# Tax              0
# ShippingCost     0
# TotalAmount      0
# PaymentMethod    0
# OrderStatus      0
# City             0
# State            0
# Country          0
# SellerID         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerID', 'CustomerName', 'ProductID',
#        'ProductName', 'Category', 'Brand', 'Quantity', 'UnitPrice', 'Discount',
#        'Tax', 'ShippingCost', 'TotalAmount', 'PaymentMethod', 'OrderStatus',
#        'City', 'State', 'Country', 'SellerID'],
#       dtype='object')

# %%
df.shape
# Out:
# (100000, 20)

# %%
df.dtypes
# Out:
# OrderID           object
# OrderDate         object
# CustomerID        object
# CustomerName      object
# ProductID         object
# ProductName       object
# Category          object
# Brand             object
# Quantity           int64
# UnitPrice        float64
# Discount         float64
# Tax              float64
# ShippingCost     float64
# TotalAmount      float64
# PaymentMethod     object
# OrderStatus       object
# City              object
# State             object
# Country           object
# SellerID          object
# dtype: object

# %%
df.sort_values('TotalAmount',ascending=False)
# Out:
#           OrderID   OrderDate  CustomerID  CustomerName ProductID  \
# 48442  ORD0048443  12-01-2020  CUST010794  Anjali Patel    P00033
# 81886  ORD0081887  26-09-2020  CUST031626  Vivaan Joshi    P00048
# 4196   ORD0004197  22-02-2021  CUST022868   Kabir Gupta    P00029
# 1929   ORD0001930  18-08-2023  CUST031209   Pooja Patel    P00025
# 58204  ORD0058205  19-10-2021  CUST033287   Priya Gupta    P00031
# ...           ...         ...         ...           ...       ...
# 38172  ORD0038173  18-06-2022  CUST025567   Pooja Kumar    P00040
# 99805  ORD0099806  29-03-2024  CUST017538   Sneha Gupta    P00029
# 4730   ORD0004731  10-07-2023  CUST043142   Karan Mehta    P00007
# 68176  ORD0068177  29-03-2020  CUST004688  Mohit Kapoor    P00039
# 86771  ORD0086772  03-02-2022  CUST043262   Aarav Singh    P00029
#
#                ProductName           Category       Brand  Quantity  \
# 48442        Puzzle 1000pc     Home & Kitchen  UrbanStyle         5
# ...

# %%
df.query('TotalAmount >2000')
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 5      ORD0000006  31-12-2022  CUST042705   Karan Sharma    P00023
# 17     ORD0000018  21-05-2022  CUST038237   Anjali Verma    P00039
# 18     ORD0000019  14-08-2024  CUST040211   Aditya Mehta    P00033
# 21     ORD0000022  25-08-2023  CUST048817   Pooja Sharma    P00010
# 22     ORD0000023  08-02-2022  CUST048828   Simran Reddy    P00003
# ...           ...         ...         ...            ...       ...
# 99970  ORD0099971  11-01-2024  CUST034218   Kabir Sharma    P00014
# 99974  ORD0099975  25-04-2024  CUST040916   Sahil Kapoor    P00023
# 99983  ORD0099984  14-02-2024  CUST033303    Arjun Mehta    P00027
# 99986  ORD0099987  21-07-2021  CUST033288    Aarav Patel    P00007
# 99996  ORD0099997  24-11-2021  CUST031254  Sunita Kapoor    P00046
#
#                ProductName           Category      Brand  Quantity  UnitPrice  \
# 5             Cookware Set              Books   ReadMore         4     449.73
# ...

# %%
df['ProductName'].value_counts()
# Out:
# ProductName
# LED Desk Lamp                  2098
# Water Bottle                   2088
# Cookware Set                   2058
# Electric Kettle                2054
# Router                         2054
# Yoga Mat                       2041
# Memory Card 128GB              2039
# Board Game                     2039
# Smart Light Bulb               2036
# Wireless Charger               2034
# Mechanical Keyboard            2034
# Microphone                     2034
# Noise Cancelling Headphones    2031
# Portable SSD 1TB               2030
# Desk Organizer                 2026
# Drone Mini                     2026
# Action Camera                  2024
# Office Chair                   2018
# Vacuum Cleaner                 2017
# Instant Pot                    2016
# Webcam Full HD                 2013
# Gaming Mouse                   2010
# Wireless Earbuds               2008
# Air Fryer                      2007
# Dress Shirt                    2007
# ...

# %%
df['Sales']= df['Quantity'] * df['UnitPrice']

# %%
df
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  31-01-2023  CUST001504  Vihaan Sharma    P00014
# 1      ORD0000002  30-12-2023  CUST000178    Pooja Kumar    P00040
# 2      ORD0000003  10-05-2022  CUST047516    Sneha Singh    P00044
# 3      ORD0000004  18-07-2023  CUST030059   Vihaan Reddy    P00041
# 4      ORD0000005  04-02-2023  CUST048677  Aditya Kapoor    P00029
# ...           ...         ...         ...            ...       ...
# 99995  ORD0099996  07-03-2023  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  24-11-2021  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  29-04-2023  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  01-11-2021  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  04-12-2021  CUST029492   Sunita Reddy    P00019
#
#                ProductName           Category       Brand  Quantity  \
# 0               Drone Mini              Books   BrightLux         3
# ...

# %%
df['Sales'].sum()
# Out:
# np.float64(91021212.99000001)

# %%
pd.pivot_table(df, values='TotalAmount' , index= 'Category' , aggfunc=['sum','mean'])
# Out:
#                            sum        mean
#                    TotalAmount TotalAmount
# Category
# Books              15261837.01  911.045667
# Clothing           15253397.50  927.878673
# Electronics        15584217.18  924.714720
# Home & Kitchen     15163939.36  912.940359
# Sports & Outdoors  15345571.88  913.209467
# Toys & Games       15216684.99  919.881815

# %%
df.groupby('ProductName')['TotalAmount'].sum()
# Out:
# ProductName
# 4K Monitor                     1866774.35
# Action Camera                  1829029.24
# Air Fryer                      1789927.34
# Backpack                       1749971.14
# Bluetooth Speaker              1803356.76
# Board Game                     1863310.96
# Car Charger                    1779795.27
# Children's Book                1738112.57
# Cookware Set                   1877038.73
# Desk Organizer                 1843103.26
# Desk Plant                     1759672.62
# Dress Shirt                    1896765.36
# Drone Mini                     1816203.39
# Electric Kettle                1905751.79
# External HDD 2TB               1786108.33
# Fitness Band                   1784149.50
# Gaming Mouse                   1895103.98
# Graphic Tablet                 1786772.26
# HDMI Cable 2m                  1847856.25
# Instant Pot                    1838639.12
# Jeans                          1882591.82
# Kids Toy Car                   1891082.43
# ...

# %%
df.groupby('Country')['TotalAmount'].sum()
# Out:
# Country
# Australia          3789106.44
# Canada             5323757.00
# India             13875839.12
# United Kingdom     4526896.86
# United States     64310048.50
# Name: TotalAmount, dtype: float64

# %%
df.loc[df['Sales']>1000]
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 4      ORD0000005  04-02-2023  CUST048677  Aditya Kapoor    P00029
# 5      ORD0000006  31-12-2022  CUST042705   Karan Sharma    P00023
# 11     ORD0000012  23-05-2023  CUST046088    Karan Kumar    P00042
# 12     ORD0000013  26-11-2020  CUST026576  Simran Kapoor    P00018
# 13     ORD0000014  22-01-2024  CUST006051   Pooja Sharma    P00040
# ...           ...         ...         ...            ...       ...
# 99986  ORD0099987  21-07-2021  CUST033288    Aarav Patel    P00007
# 99989  ORD0099990  12-05-2021  CUST005788    Aarav Reddy    P00016
# 99993  ORD0099994  04-05-2023  CUST045239   Mohit Sharma    P00029
# 99994  ORD0099995  09-01-2022  CUST028035   Kabir Kapoor    P00011
# 99996  ORD0099997  24-11-2021  CUST031254  Sunita Kapoor    P00046
#
#                ProductName           Category       Brand  Quantity  \
# 4                  T-Shirt           Clothing    KiddoFun         2
# ...

# %%
#  Chaining Method

data=(
    df
    .query("Sales > 1000 and Country=='India'")
    .sort_values('Sales' , ascending=False)
)
data
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 58985  ORD0058986  12-05-2022  CUST031096     Aman Singh    P00028
# 24565  ORD0024566  11-09-2020  CUST023461   Vivaan Gupta    P00014
# 71304  ORD0071305  23-10-2022  CUST025737    Karan Patel    P00043
# 33003  ORD0033004  30-10-2022  CUST039524   Sneha Kapoor    P00037
# 42951  ORD0042952  19-01-2020  CUST006522    Sahil Gupta    P00038
# ...           ...         ...         ...            ...       ...
# 2641   ORD0002642  22-05-2020  CUST046780   Simran Patel    P00004
# 67945  ORD0067946  11-04-2024  CUST031000   Aditya Reddy    P00016
# 56193  ORD0056194  04-09-2023  CUST012954    Sahil Gupta    P00049
# 20067  ORD0020068  18-09-2021  CUST038392     Aman Joshi    P00027
# 3879   ORD0003880  29-08-2023  CUST003123  Vihaan Kapoor    P00032
#
#             ProductName           Category       Brand  Quantity  UnitPrice  \
# 58985             Jeans              Books   BrightLux         5     599.80
# ...

# %%
df['OrderID'].count()
# Out:
# np.int64(100000)

# %%
df['Previous_sales']=df['Sales'].shift(1)

# %%
df
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  31-01-2023  CUST001504  Vihaan Sharma    P00014
# 1      ORD0000002  30-12-2023  CUST000178    Pooja Kumar    P00040
# 2      ORD0000003  10-05-2022  CUST047516    Sneha Singh    P00044
# 3      ORD0000004  18-07-2023  CUST030059   Vihaan Reddy    P00041
# 4      ORD0000005  04-02-2023  CUST048677  Aditya Kapoor    P00029
# ...           ...         ...         ...            ...       ...
# 99995  ORD0099996  07-03-2023  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  24-11-2021  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  29-04-2023  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  01-11-2021  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  04-12-2021  CUST029492   Sunita Reddy    P00019
#
#                ProductName           Category       Brand  Quantity  \
# 0               Drone Mini              Books   BrightLux         3
# ...

# %%
from sqlalchemy import create_engine

username='root'
password='mysql12'
host='localhost'
port='3306'
database='project'

engine=create_engine(
    f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}"
)

table_name='amazon'

df.to_sql(table_name , engine , if_exists='replace',index=False)

print(" Amazon Data Successfully Loaded into the mysql")
# Out:
#  Amazon Data Successfully Loaded into the mysql

# %%
df.shape
# Out:
# (100000, 22)
